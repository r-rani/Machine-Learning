# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans #for now go from scratch later
image= mpl.image.imread("img1lab3.jpeg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 5
#       2 import matplotlib.pyplot as plt
#       4 from sklearn.cluster import KMeans #for now go from scratch later
# ----> 5 image= mpl.image.imread("img1lab3.jpeg")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\image.py:1502, in imread(fname, format)
#    1495 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1496     # Pillow doesn't handle URLs directly.
#    1497     raise ValueError(
#    1498         "Please open the URL for reading and pass the "
#    1499         "result to Pillow, e.g. with "
#    1500         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1501         )
# -> 1502 with img_open(fname) as image:
#    1503     return (_pil_png_to_float_array(image)
#    1504             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
# ...
