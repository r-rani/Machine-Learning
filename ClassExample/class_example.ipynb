# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()
#print(diabetes.DESCR)
X_data, t = load_diabetes(return_X_y=True)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, t_train, t_test = train_test_split(X_data, t, test_size = 0.2, random_state = 10)

# %%
print(X_train.shape)
# Out:
# (353, 10)

# %%
print(X_test.shape)
# Out:
# (89, 10)

# %%
plt.scatter(X_train[:,2], t_train, color='magenta')
plt.show(0)

# %%
N=len(X_train)
M=len(X_test)
#print (N,M)
# Out:
# 353 89

# %%
new_col = np.ones(N);
#print (new_col.shape)
# Out:
# (353,)

# %%
X = np.insert(X_train, 0, new_col, axis=1)
#print(X[:4,:4])
# Out:
# [[ 1.          0.00538306 -0.04464164  0.05954058]
#  [ 1.         -0.02730979 -0.04464164  0.08001901]
#  [ 1.          0.0090156  -0.04464164 -0.02452876]
#  [ 1.          0.01628068  0.05068012  0.07247433]]

# %%
A=np.dot(
